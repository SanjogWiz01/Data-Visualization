# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('collection_data.csv')
print(df) # orginal data tracking there is nan value also
# Out:
#          date  temperature  humidity  rainfall
# 0  2026-01-01         18.0        65         0
# 1  2026-01-02         19.0        60         0
# 2  2026-01-03         17.0        70         5
# 3  2026-01-04         21.0        55         0
# 4  2026-01-05          NaN        58         2
# 5  2026-01-06         23.0        50         0
# 6  2026-01-07         25.0        45         0
# 7  2026-01-08         24.0        48         1
# 8  2026-01-09         22.0        52         0
# 9  2026-01-10         20.0        60         3

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df
# Out:
#         date  temperature  humidity  rainfall
# 0 2026-01-01         18.0        65         0
# 1 2026-01-02         19.0        60         0
# 2 2026-01-03         17.0        70         5
# 3 2026-01-04         21.0        55         0
# 4 2026-01-05          NaN        58         2
# 5 2026-01-06         23.0        50         0
# 6 2026-01-07         25.0        45         0
# 7 2026-01-08         24.0        48         1
# 8 2026-01-09         22.0        52         0
# 9 2026-01-10         20.0        60         3

# %%
# Fill missing temperature with mean temperature
df["temperature"] = df["temperature"].fillna(df["temperature"].mean())

print("\nAfter cleaning:")
print(df)
# Out:
# After cleaning:
#         date  temperature  humidity  rainfall
# 0 2026-01-01         18.0        65         0
# 1 2026-01-02         19.0        60         0
# 2 2026-01-03         17.0        70         5
# 3 2026-01-04         21.0        55         0
# 4 2026-01-05         21.0        58         2
# 5 2026-01-06         23.0        50         0
# 6 2026-01-07         25.0        45         0
# 7 2026-01-08         24.0        48         1
# 8 2026-01-09         22.0        52         0
# 9 2026-01-10         20.0        60         3

# %%
# now analizing the real data using libary
# Hottest and coldest day
hottest_day = df.loc[df["temperature"].idxmax()]
coldest_day = df.loc[df["temperature"].idxmin()]

print("\nHottest day:")
print(hottest_day)

print("\nColdest day:")
print(coldest_day)
# Out:
# Hottest day:
# date           2026-01-07 00:00:00
# temperature                   25.0
# humidity                        45
# rainfall                         0
# Name: 6, dtype: object
#
# Coldest day:
# date           2026-01-03 00:00:00
# temperature                   17.0
# humidity                        70
# rainfall                         5
# Name: 2, dtype: object

# %%
temps = df["temperature"].to_numpy()  # using this function to find the stasts using numpy

print("\nTemperature stats:")
print("Mean:", np.mean(temps))
print("Max:", np.max(temps))
print("Min:", np.min(temps))
# Out:
# Temperature stats:
# Mean: 21.0
# Max: 25.0
# Min: 17.0

# %%
plt.figure()
plt.plot(df["date"], df["temperature"])
plt.title("Temperature Over Time")
plt.xlabel("Date")
plt.ylabel("Temperature (°C)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# FOR THE RAIN FALL BAR CHART
plt.figure()
plt.bar(df["date"], df["rainfall"])
plt.title("Daily Rainfall")
plt.xlabel("Date")
plt.ylabel("Rainfall (mm)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
print("\nInsights:")
print("Average temperature:", round(df['temperature'].mean(), 2))
print("Total rainfall:", df["rainfall"].sum(), "mm")
# Out:
# Insights:
# Average temperature: 21.0
# Total rainfall: 11 mm
