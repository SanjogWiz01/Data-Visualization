# %%
import pandas as pd

# %%
df=pd.read_csv('problem1.csv')
df
# Out:
#    Product A  Product B  Product C  Unnamed: 3
# 0         30         21          9         NaN
# 1         35         34          1         NaN
# 2         41         11         11         NaN

# %%
df[['Product A', 'Product B']]
# Out:
#    Product A  Product B
# 0         30         21
# 1         35         34
# 2         41         11
