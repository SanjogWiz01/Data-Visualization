# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=[1,2,3,4,5]
y=[5,9,45,86,100]

# %%
plt.bar(x,y)
plt.show()

# %%
plt.hist(x)
plt.xlabel("time",color='red')
plt.details(color='green')
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 3
#       1 plt.hist(x)
#       2 plt.xlabel("time",color='red')
# ----> 3 plt.details(color='green')
#       4 plt.show
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'details'

# %%
plt.pie(x,labels=y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
